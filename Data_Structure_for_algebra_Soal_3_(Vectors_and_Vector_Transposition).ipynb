# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_3_(Vectors_and_Vector_Transposition).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 3

# %%
import numpy as np

# %%
import tensorflow as tf

# %%
import torch

# %%
#lakukan soal nomor 2 menggunakan pytorch dan tensorflow

# %% [markdown]
# Tensorflow

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_tf (Tensorflow)
x_tf = tf.Variable([[10],
                    [15],
                    [20]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=int32, numpy=
# array([[10],
#        [15],
#        [20]], dtype=int32)>

# %%
#tampilkan ukuran dari vector x_tf (Tensorflow)
x_tf.shape
# Out:
# TensorShape([3, 1])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_tf (Tensorflow)
y_tf = tf.Variable([[10],
                    [15],
                    [20]])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=int32, numpy=
# array([[10],
#        [15],
#        [20]], dtype=int32)>

# %%
#tampilkan ukuran dari vector y_tf (Tensorflow)
y_tf.shape
# Out:
# TensorShape([3, 1])

# %% [markdown]
# Pytorch

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_pt (Pytorch)
x_pt = torch.tensor([[10],
                    [15],
                    [20]])
x_pt
# Out:
# tensor([[10],
#         [15],
#         [20]])

# %%
#tampilkan ukuran dari vector x_pt (Pytorch)
x_pt.shape
# Out:
# torch.Size([3, 1])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_pt (Pytorch)
y_pt = torch.tensor([[10],
                    [15],
                    [20]])
y_pt
# Out:
# tensor([[10],
#         [15],
#         [20]])

# %%
#tampilkan ukuran dari vector y_pt (Pytorch)
y_pt.shape
# Out:
# torch.Size([3, 1])
