# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_2_(Norms_and_Unit_Vectors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Soal 1

# %%
#buat vector x dengan ukuran 3x1
x = np.array([[67],
              [76],
              [97]])
x
# Out:
# array([[67],
#        [76],
#        [97]])

# %%
#hitung nilai L2 norm dari vector x
(67**2 + 76**2 + 97**2)**(1/2)
# Out:
# 140.2640367307315

# %% [markdown]
# Soal 2

# %%
#buat vector v dengan elemen (3,4)
v = np.array([3, 4])
v
# Out:
# array([3, 4])

# %%
#hitung nilai L2 norm dari vector v
norm = np.linalg.norm(v)
norm
# Out:
# np.float64(5.0)

# %%
#tampilkan unit vector dari vector v
unit_v = v / norm
print(f'Unit v: {unit_v}')
# Out:
# Unit v: [0.6 0.8]

# %%
#hitung panjang unit vector dari vector v
print(f'Panjang unit v: {np.linalg.norm(unit_v)}')
# Out:
# Panjang unit v: 1.0
