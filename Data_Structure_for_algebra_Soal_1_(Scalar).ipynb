# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_(Scalar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sub-bab Scalar

# %% [markdown]
# Soal no 1

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 10
x
# Out:
# int

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 80

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
type(y)
# Out:
# int

# %%
#jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 90

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 67.7

# %%
#jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 147.7

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float
