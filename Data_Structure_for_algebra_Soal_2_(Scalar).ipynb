# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_2_(Scalar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal No 2

# %%
#lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat variabel skalar x_tf dan simpan suatu nilai skalar (Tensorflow)
x_tf = tf.Variable(10)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=10>

# %%
#tampilkan tipe data dari x_tf (Tensorflow)
print(x_tf.dtype)
# Out:
# <dtype: 'int32'>

# %%
#buat variabel skalar y_tf dan simpan suatu nilai skalar (Tensorflow)
y_tf = tf.Variable(80)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=80>

# %%
#tampilkan tipe data dari y_tf (Tensorflow)
print(y_tf.dtype)
# Out:
# <dtype: 'int32'>

# %%
#jumlahkan x_tf+y_tf (Tensorflow)
x_sum = x_tf + y_tf
x_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=90>

# %%
#buat variabel bernama x_float_tf dan simpan suatu nilai desimal (Tensorflow)
x_float_tf = tf.Variable(67.7)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=67.69999694824219>

# %%
#jumlahkan x_float_tf dengan y_tf (Tensorflow)
hasil_sum = x_float_tf + tf.cast(y_tf, tf.float32)
hasil_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=147.6999969482422>

# %%
#tampilkan tipe data dari x_float_tf (Tensorflow)
type = print(x_float_tf.dtype)
# Out:
# <dtype: 'float32'>
