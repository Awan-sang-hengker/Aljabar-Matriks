# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_2_(Vectors_and_Vector_Transposition).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
#buat vector x dengan ukuran 3x1
x = np.array([76, 67, 12])
x
# Out:
# array([76, 67, 12])

# %%
#hitung panjang vector x
len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
#tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
#akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(76)

# %%
#tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# Soal 2

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_t
x_trans = x.T
x_trans
# Out:
# array([76, 67, 12])

# %%
#tampilkan ukuran dari vector x_t
x_trans.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[76],
              [67],
              [12]])
y
# Out:
# array([[76],
#        [67],
#        [12]])

# %%
#tampilkan ukuran dari vector x_t
y.shape
# Out:
# (3, 1)
