# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_(Generic_Tensor_Notation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 1

# %%
import tensorflow as tf

# %%
import torch

# %%
#jelaskan tentang perintah ini
#images_pt = torch.zeros([32, 28, 28, 3])

images_pt = torch.zeros([32, 28, 28, 3])

images_pt

# %%
"""
PENJELASAN

1. torch.zeros(shape)
Fungsi torch.zeros() digunakan untuk membuat tensor (array multidimensi)
yang seluruh elemennya bernilai 0.

2. Arti dari shape [32, 28, 28, 3]
Shape ini menunjukkan dimensi dari tensor yang dibuat:

- 32  : jumlah data (batch size), artinya ada 32 gambar
- 28  : tinggi gambar (height) dalam pixel
- 28  : lebar gambar (width) dalam pixel
- 3   : jumlah channel warna (RGB = Red, Green, Blue)

3. Makna keseluruhan
Perintah:
torch.zeros([32, 28, 28, 3])

artinya:
- Membuat 32 buah gambar
- Setiap gambar berukuran 28 x 28 pixel
- Setiap pixel memiliki 3 channel warna (RGB)
- Semua nilai pixel = 0 (yang berarti warna hitam)

4. Kenapa outputnya semua 0?
Karena fungsi yang digunakan adalah torch.zeros(),
maka seluruh elemen tensor otomatis diisi dengan nilai 0.
Tidak ada nilai lain kecuali 0.
"""
