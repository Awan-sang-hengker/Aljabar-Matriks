# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_3_(Scalar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 3

# %%
#lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
#buat variabel skalar x_pt dan simpan suatu nilai skalar (Pytorch)
x_pt = torch.tensor(10)
x_pt
# Out:
# tensor(10)

# %%
#tampilkan tipe data dari x_pt (Pytorch)
type(x_pt)
# Out:
# torch.Tensor

# %%
#buat variabel skalar y_pt dan simpan suatu nilai skalar (Pytorch)
y_pt = torch.tensor(80)

# %%
#tampilkan tipe data dari y_pt (Pytorch)
type(y_pt)
# Out:
# torch.Tensor

# %%
#jumlahkan x_pt+y_pt (Pytorch)
py_sum = x_pt + y_pt
py_sum
# Out:
# tensor(90)

# %%
#buat variabel bernama x_float_pt dan simpan suatu nilai desimal (Pytorch)
x_float_pt = torch.tensor(67.7)
x_float_pt
# Out:
# tensor(67.7000)

# %%
#jumlahkan x_float_pt dengan y_pt
py_sum2 = x_float_pt + y_pt
py_sum2
# Out:
# tensor(147.7000)

# %%
#tampilkan tipe data dari x_float
type(x_float_pt)
# Out:
# torch.Tensor
