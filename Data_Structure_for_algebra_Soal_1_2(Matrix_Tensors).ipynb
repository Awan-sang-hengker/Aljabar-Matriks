# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_2(Matrix_Tensors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[1, 2, 3], [67, 76, 97]])
X
# Out:
# array([[ 1,  2,  3],
#        [67, 76, 97]])

# %%
#tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([ 1, 67])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([67, 76, 97])

# %% [markdown]
# Soal 2

# %%
#ulangi soal nomor 1 menggunakan pytorch

# %%
#buat matrix X_pt berukuran 2x3 menggunakan numpy (Pytorch)
X_pt = torch.tensor([[1, 2, 3], [67, 76, 97]])
X_pt
# Out:
# tensor([[ 1,  2,  3],
#         [67, 76, 97]])

# %%
#tampilkan ukuran dari matrix X_pt
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X_pt
X_pt[:,0]
# Out:
# tensor([ 1, 67])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X_pt
X_pt[1,:]
# Out:
# tensor([67, 76, 97])

# %%
#ulangi soal nomor 1 menggunakan tensorflow
X_tf = tf.Variable([[1, 2, 3], [67, 76, 97]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 1,  2,  3],
#        [67, 76, 97]], dtype=int32)>

# %%
#tampilkan ukuran dari matrix X_tf
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X_tf
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 1, 67], dtype=int32)>

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X_tf
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([67, 76, 97], dtype=int32)>
