# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_(Exercises_on_Algebra_Data_Structures).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 1

# %% [markdown]
# ![image_2026-04-12_233515620.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
x = np.array([[25],
      [2],
      [-3],
      [-23]])
x

x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
