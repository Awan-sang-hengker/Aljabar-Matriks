# %% [markdown]
# <a href="https://colab.research.google.com/github/Awan-sang-hengker/Aljabar-Matriks/blob/main/Data_Structure_for_algebra_Soal_1_2_(Basis%2C_Orthogonal%2C_and_Orthonormal_Vectors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
#buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)

# %%
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1])
j
# Out:
# array([0, 1])

# %%
#buktikan bahwa vector i dan vector j itu orthogonal
proof1 = np.dot(i, j)
if bukti1 == 0:
  print(f'Jadi i dan j adalah orthogonal karena (1, 0) . (0, 1) = (1 x 0) + (0 x 1) = {bukti1}')
else:
  print(f'i dan j bukan orthogonal karena hasilnya {proof1}')
# Out:
# Jadi i dan j adalah orthogonal karena (1, 0) . (0, 1) = (1 x 0) + (0 x 1) = 0

# %% [markdown]
# Soal 2

# %%
#Bagaimana dengan v=(1,2) dan w=(2,-1), apakah juga orthogonal?
v = np.array([1, 2])
w = np.array([2, -1])
proof2 = np.dot(v, w)
if proof2 == 0:
  print(f'v dan w adalah orthogonal, karena hasilnya: {proof2}')
else:
  print(f'v dan w bukanlah orthogonal karena hasilnya: {proof2}')
# Out:
# v dan w adalah orthogonal, karena hasilnya: 0
